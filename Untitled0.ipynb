# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Colab Notebooks/
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
income = pd.read_csv('income.csv')
income.head()
# Out:
#    ID  Income  Age  Education  Gender
# 0   1     113   69         12       1
# 1   2      91   52         18       0
# 2   3     121   65         14       0
# 3   4      81   58         12       0
# 4   5      68   31         16       1

# %%
income.describe()
# Out:
#                 ID       Income          Age    Education       Gender
# count  1500.000000  1500.000000  1500.000000  1500.000000  1500.000000
# mean    750.500000    75.986000    43.582000    14.681333     0.490000
# std     433.157015    20.005215    15.169466     2.693812     0.500067
# min       1.000000    14.000000    18.000000    10.000000     0.000000
# 25%     375.750000    62.000000    30.000000    12.000000     0.000000
# 50%     750.500000    76.000000    44.000000    15.000000     0.000000
# 75%    1125.250000    91.000000    57.000000    16.000000     1.000000
# max    1500.000000   134.000000    70.000000    20.000000     1.000000

# %%
income.isnull().sum()
# Out:
# ID           0
# Income       0
# Age          0
# Education    0
# Gender       0
# dtype: int64

# %%
income.corr()
# Out:
#                  ID    Income       Age  Education    Gender
# ID         1.000000 -0.038846 -0.037770  -0.074147  0.005246
# Income    -0.038846  1.000000  0.761486   0.256634 -0.045060
# Age       -0.037770  0.761486  1.000000   0.026254 -0.027242
# Education -0.074147  0.256634  0.026254   1.000000 -0.004843
# Gender     0.005246 -0.045060 -0.027242  -0.004843  1.000000

# %%
plt.figure()
sns.heatmap(income.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heat")
plt.show()

# %%
x = income[['Age']]
y = income['Income']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([ 63.16125141,  61.1607887 ,  98.16934881,  56.15963193,
#         62.16102005,  90.16749798,  80.16518443,  88.16703527,
#         85.16634121,  91.16772933,  64.16148276,  66.16194547,
#         61.1607887 ,  55.15940057,  95.16865475,  80.16518443,
#         92.16796069,  92.16796069,  89.16726662,  97.16911746,
#         80.16518443,  92.16796069,  93.16819204,  66.16194547,
#         73.16356495,  83.1658785 ,  54.15916922,  69.16263953,
#         77.16449037,  77.16449037,  84.16610985,  88.16703527,
#         66.16194547,  71.16310224,  87.16680391,  64.16148276,
#         95.16865475,  78.16472172,  99.16958017,  89.16726662,
#         69.16263953,  62.16102005,  63.16125141,  63.16125141,
#         87.16680391,  82.16564714,  68.16240818,  79.16495308,
#         97.16911746,  70.16287089,  94.16842339,  73.16356495,
#         62.16102005,  90.16749798,  99.16958017,  74.16379631,
#         82.16564714,  62.16102005,  95.16865475,  67.16217683,
# ...

# %%
mse = mean_squared_error(y_test, y_pred)
print(f"\nMean Squared Error: {mse}")
# Out:
# Mean Squared Error: 139.22052499292565

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='blue', label='Actual Data')
plt.plot(x, model.predict(x), color='red', label='LinearRegression Line')
plt.title("Age vs Income")
plt.xlabel("Age")
plt.ylabel("Income")
plt.legend()
plt.show()

# %% [markdown]
# # **R SCript**

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# income <- read.table("income.csv", header = TRUE, sep = ",")
# summary(income)
# Out:
#        ID             Income            Age          Education
#  Min.   :   1.0   Min.   : 14.00   Min.   :18.00   Min.   :10.00
#  1st Qu.: 375.8   1st Qu.: 62.00   1st Qu.:30.00   1st Qu.:12.00
#  Median : 750.5   Median : 76.00   Median :44.00   Median :15.00
#  Mean   : 750.5   Mean   : 75.99   Mean   :43.58   Mean   :14.68
#  3rd Qu.:1125.2   3rd Qu.: 91.00   3rd Qu.:57.00   3rd Qu.:16.00
#  Max.   :1500.0   Max.   :134.00   Max.   :70.00   Max.   :20.00
#      Gender
#  Min.   :0.00
#  1st Qu.:0.00
#  Median :0.00
#  Mean   :0.49
#  3rd Qu.:1.00
#  Max.   :1.00

# %%
# %%R
# traindata <- as.data.frame(income[1:1400,])
# traindata
# testdata <- as.data.frame(income[1401:1410,])
# testdata

# %%
# %%R
# plot(traindata$Age, traindata$Income)

# %%
# %%R
# LR1 = lm (Income ~ Age, traindata)
# summary (LR1)
# Out:
# Call:
# lm(formula = Income ~ Age, data = traindata)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -43.349  -9.150   0.597   8.739  41.842
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 32.00509    1.05962   30.20   <2e-16 ***
# Age          1.00636    0.02297   43.82   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 13.08 on 1398 degrees of freedom
# Multiple R-squared:  0.5787,	Adjusted R-squared:  0.5784
# F-statistic:  1920 on 1 and 1398 DF,  p-value: < 2.2e-16

# %%
# %%R
# plot(traindata$Age, traindata$Income)
# abline(LR1, col=2, lwd = 3)
